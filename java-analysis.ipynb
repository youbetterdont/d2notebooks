# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
cs_damage = lambda x: (x*28 - 278 + 1)/2.0
slvl = np.arange(28,60)
synergy_hard_points = 80
synergy_bonus = synergy_hard_points*0.1

synergized_dmg = cs_damage(slvl)*(1+synergy_bonus)

plt.figure()
plt.plot(slvl[1:], (synergized_dmg[1:]-synergized_dmg[:-1])/synergized_dmg[:-1]*100)
plt.xlabel('skill level')
plt.ylabel('percent dmg increase per skill point')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0,0.5,'percent dmg increase per skill point')

# %% [markdown]
# ## Breakpoints
#
# | Frames | APS | Attack | Throw | APS Increase |
# |--------|-----|--------|-------|--------------|
# |  14    | 1.78| --     | 0     | --           |
# |  13    | 1.92| --     | 6     | 7.9%         |
# |  12    | 2.08| --     | 16    | 8.3%         |
# |  11    | 2.27| 0      | 30    | 9.1%         |
# |  10    | 2.5 | 10     | 52    | 10.1%        |
# |   9    | 2.77| 26     | 89    | 10.8%        |
# |   8    | 3.12| 50     | --    | 12.6%        |
# |   7    | 3.57| 95     | --    | 14.4%        |
#
# Good targets: 30, 52, 95
#
# Using IAS jewels in helm and body armor and cat's eye, we can get 50 IAS. This is good enough for 8 frame CS and 11 frame throw. With only an additional 2 IAS we could get to 10 frame throw.
#
# What's the best possible setup?
#
# * griff's
# * tstrokes
# * 3/20 gloves
# * razor
# * skill ring
# * ravenfrost
# * cat's eye
#
# * 55 IAS
#
# ## No griffs
#
#
# ### Option 1
#
# * Tstrokes (15)
# * Ormus w/ IAS jewel (15)
# * Cat's eye (20)
# * Kira's w/ IAS jewel (15)
